# %%
df_train = pd.read_csv("train_no_missing.csv")
df_test = pd.read_csv("test_no_missing.csv")

# %%
nuTocaList = ["MSSubClass", "MoSold", "YrSold", "OverallQual"]
df_train[nuTocaList] = df_train[nuTocaList].astype("str")
df_test[nuTocaList] = df_test[nuTocaList].astype("str")

# %%
df_all = pd.concat([df_train, df_test])
df_all.reset_index(drop = True, inplace = True)

df_all = pd.get_dummies(df_all)
df_train_dummy = df_all.iloc[:1460]
df_test_dummy = df_all.iloc[1460:]

df_test_dummy.drop("SalePriceLog", axis = 1, inplace = True)

#get numeric data and categoric data
df_train_dummy_categoric_list = list(df_train_dummy.filter(regex="_").columns)
df_train_dummy_numeric_list = list(set(df_train_dummy.columns) - set(df_train_dummy_categoric_list))
df_train_dummy_numeric_list.remove("SalePriceLog")
df_train_dummy_numeric_list.remove("Id")

print(len(df_train_dummy_categoric_list), len(df_train_dummy_numeric_list), len(list(df_train.columns)))
# Out:
# 309 32 81
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_train_numeric_list = []
df_train_categoric_list = []

for c in df_train.columns:
    if df_train[c].dtype == "int64" or df_train[c].dtype == "float64":
        df_train_numeric_list.append(c)
    else:
        df_train_categoric_list.append(c)

# df_train = pd.get_dummies(df_train)
# li_column = [c for c in df_train.columns]
        
df_train_numeric_list.remove("SalePriceLog")
df_train_numeric_list.remove("Id")

len(df_train_numeric_list)
# Out:
# 32

# %%
df_train_Fvalue_list = []

for i in df_train_categoric_list:
    model = sm.OLS.from_formula("SalePriceLog ~ C({})".format(i), data=df_train)
    result = model.fit()
    df_tmp=sm.stats.anova_lm(result)
    df_train_Fvalue_list.append(df_tmp.index[0])
    df_train_Fvalue_list.append(df_tmp['PR(>F)'][0])    

df_train_Fvalue_list
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# ['C(Alley)',
#  1.3581271402737912e-09,
#  'C(BldgType)',
#  3.436707937561439e-12,
#  'C(BsmtCond)',
#  1.4929924257982771e-27,
#  'C(BsmtExposure)',
#  7.259832389789443e-48,
#  'C(BsmtFinType1)',
#  4.320808568653022e-78,
#  'C(BsmtFinType2)',
#  6.737196485308042e-13,
#  'C(BsmtQual)',
#  2.0299696848675252e-188,
#  'C(CentralAir)',
#  9.859877510166113e-44,
#  'C(Condition1)',
#  1.173445350388663e-10,
#  'C(Condition2)',
#  0.013820426634156759,
#  'C(Electrical)',
#  6.082296090683674e-31,
#  'C(ExterCond)',
#  6.541281772505982e-14,
#  'C(ExterQual)',
#  6.930371887229339e-195,
#  'C(Exterior1st)',
#  1.053088865625971e-53,
#  'C(Exterior2nd)',
#  2.429748830868271e-49,
#  'C(Fence)',
#  6.560268328221939e-13,
#  'C(FireplaceQu)',
#  6.961918246503842e-115,
#  'C(Foundation)',
#  1.350598627695233e-111,
#  'C(Functional)',
#  4.250494469163972e-06,
#  'C(GarageCond)',
#  2.5090035073303237e-47,
#  'C(GarageFinish)',
#  4.0580664836951105e-151,
#  'C(GarageQual)',
#  6.070436449027677e-46,
#  'C(GarageType)',
#  8.430356343009874e-125,
#  'C(Heating)',
#  2.4846337250596574e-09,
#  'C(HeatingQC)',
#  1.614912464887388e-82,
#  'C(HouseStyle)',
#  1.6360138590326215e-30,
#  'C(KitchenQual)',
#  4.4388169575154893e-187,
#  'C(LandContour)',
#  3.086153886546515e-08,
#  'C(LandSlope)',
#  0.33883387690662126,
#  'C(LotConfig)',
#  6.214548326156816e-07,
#  'C(LotShape)',
#  7.856719535719276e-29,
#  'C(MSSubClass)',
#  5.0972638621500545e-115,
#  'C(MSZoning)',
#  1.021736584681163e-59,
#  'C(MasVnrType)',
#  1.6698013181048438e-65,
#  'C(MiscFeature)',
#  0.0060600044070938785,
#  'C(MoSold)',
#  0.4496614407917193,
#  'C(Neighborhood)',
#  4.041200522504586e-243,
#  'C(OverallQual)',
#  0.0,
#  'C(PavedDrive)',
#  1.0912447610801971e-31,
#  'C(PoolQC)',
#  0.007695368932191638,
#  'C(RoofMatl)',
#  0.00045040769405397445,
#  'C(RoofStyle)',
#  1.705633966971223e-12,
#  'C(SaleCondition)',
#  1.6895244708546793e-41,
#  'C(SaleType)',
#  5.4968928492999534e-36,
#  'C(Street)',
#  0.028379646829025613,
#  'C(Utilities)',
#  0.629608587053528,
#  'C(YrSold)',
#  0.5656385762808924]

# %%
df_train_dummy_Fvalue_list = []

for i in df_train_dummy_categoric_list:
    model = sm.OLS.from_formula("SalePriceLog ~ C({})".format(i), data=df_train_dummy)
    result = model.fit()
    df_tmp=sm.stats.anova_lm(result)
    df_train_dummy_Fvalue_list.append(df_tmp.index[0])
    df_train_dummy_Fvalue_list.append(df_tmp['PR(>F)'][0])  

df_train_dummy_Fvalue_list
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# ['C(Alley_Grvl)',
#  2.0478713741331746e-10,
#  'C(Alley_None)',
#  3.8837674050199886e-07,
#  'C(Alley_Pave)',
#  0.6579941021956452,
#  'C(BldgType_1Fam)',
#  3.7801110461925183e-07,
#  'C(BldgType_2fmCon)',
#  2.4538366407698522e-05,
#  'C(BldgType_Duplex)',
#  7.375814121224275e-06,
#  'C(BldgType_Twnhs)',
#  2.9332539457206603e-05,
#  'C(BldgType_TwnhsE)',
#  0.3245589721040072,
#  'C(BsmtCond_Fa)',
#  1.175868128939608e-10,
#  'C(BsmtCond_Gd)',
#  4.883571471175036e-05,
#  'C(BsmtCond_None)',
#  1.3702477867036519e-14,
#  'C(BsmtCond_Po)',
#  0.0006718668016420431,
#  'C(BsmtCond_TA)',
#  1.223822269436007e-07,
#  'C(BsmtExposure_Av)',
#  5.121317947759249e-08,
#  'C(BsmtExposure_Gd)',
#  5.61178174092972e-26,
#  'C(BsmtExposure_Mn)',
#  0.04879616927807606,
#  'C(BsmtExposure_No)',
#  1.120416359008796e-19,
#  'C(BsmtExposure_None)',
#  1.3702477867036519e-14,
#  'C(BsmtFinType1_ALQ)',
#  0.0043357107412054455,
#  'C(BsmtFinType1_BLQ)',
#  4.5441990726906435e-07,
#  'C(BsmtFinType1_GLQ)',
#  1.9308466087471736e-70,
#  'C(BsmtFinType1_LwQ)',
#  0.0015898188926548368,
#  'C(BsmtFinType1_None)',
#  1.3702477867036519e-14,
#  'C(BsmtFinType1_Rec)',
#  1.928732765382826e-07,
#  'C(BsmtFinType1_Unf)',
#  0.0002003898736673515,
#  'C(BsmtFinType2_ALQ)',
#  0.11625191934597334,
#  'C(BsmtFinType2_BLQ)',
#  0.04802935288217358,
#  'C(BsmtFinType2_GLQ)',
#  0.9286725241863851,
#  'C(BsmtFinType2_LwQ)',
#  0.5544028173481194,
#  'C(BsmtFinType2_None)',
#  1.3702477867036519e-14,
#  'C(BsmtFinType2_Rec)',
#  0.2655667970471078,
#  'C(BsmtFinType2_Unf)',
#  2.7588102665304954e-06,
#  'C(BsmtQual_Ex)',
#  7.874483496228947e-79,
#  'C(BsmtQual_Fa)',
#  8.822874448932131e-10,
#  'C(BsmtQual_Gd)',
#  1.844308123610229e-39,
#  'C(BsmtQual_None)',
#  1.3702477867036519e-14,
#  'C(BsmtQual_TA)',
#  4.643522517504711e-84,
#  'C(CentralAir_N)',
#  9.859877510177042e-44,
#  'C(CentralAir_Y)',
#  9.859877510166113e-44,
#  'C(Condition1_Artery)',
#  5.80460926003395e-07,
#  'C(Condition1_Feedr)',
#  1.7060116103235008e-06,
#  'C(Condition1_Norm)',
#  5.542031856348877e-06,
#  'C(Condition1_PosA)',
#  0.04473258095448559,
#  'C(Condition1_PosN)',
#  0.01872816084010903,
#  'C(Condition1_RRAe)',
#  0.09268342592476586,
#  'C(Condition1_RRAn)',
#  0.5221723192819105,
#  'C(Condition1_RRNe)',
#  0.6339381897984858,
#  'C(Condition1_RRNn)',
#  0.38481579837400404,
#  'C(Condition2_Artery)',
#  0.10775287500389628,
#  'C(Condition2_Feedr)',
#  0.029831076065830072,
#  'C(Condition2_Norm)',
#  0.0833475131931783,
#  'C(Condition2_PosA)',
#  0.0945972628620386,
#  'C(Condition2_PosN)',
#  0.09602275677224816,
#  'C(Condition2_RRAe)',
#  0.7435026603546864,
#  'C(Condition2_RRAn)',
#  0.6219180288790052,
#  'C(Condition2_RRNn)',
#  0.03695941385842625,
#  'C(Electrical_FuseA)',
#  2.1047391756386572e-20,
#  'C(Electrical_FuseF)',
#  1.5327677444203027e-10,
#  'C(Electrical_FuseP)',
#  0.012177903152413712,
#  'C(Electrical_Mix)',
#  0.022384557822974972,
#  'C(Electrical_SBrkr)',
#  5.0898692458002915e-33,
#  'C(ExterCond_Ex)',
#  0.6780814661885867,
#  'C(ExterCond_Fa)',
#  1.5597381109172158e-14,
#  'C(ExterCond_Gd)',
#  0.08168966175439803,
#  'C(ExterCond_Po)',
#  0.05104284435030302,
#  'C(ExterCond_TA)',
#  9.483686981794064e-07,
#  'C(ExterQual_Ex)',
#  6.71258216057363e-45,
#  'C(ExterQual_Fa)',
#  8.928233429321328e-12,
#  'C(ExterQual_Gd)',
#  2.402983587588521e-97,
#  'C(ExterQual_TA)',
#  4.746814688472045e-141,
#  'C(Exterior1st_AsbShng)',
#  1.5190287548330184e-08,
#  'C(Exterior1st_AsphShn)',
#  0.20064845738660803,
#  'C(Exterior1st_BrkComm)',
#  0.002136197145192214,
#  'C(Exterior1st_BrkFace)',
#  0.24845474714587246,
#  'C(Exterior1st_CBlock)',
#  0.24707164420735778,
#  'C(Exterior1st_CemntBd)',
#  0.0002957220037867527,
#  'C(Exterior1st_HdBoard)',
#  0.0034394696010435844,
#  'C(Exterior1st_ImStucc)',
#  0.25774883755377703,
#  'C(Exterior1st_MetalSd)',
#  2.6231045355593593e-11,
#  'C(Exterior1st_Plywood)',
#  0.6427198632385827,
#  'C(Exterior1st_Stone)',
#  0.12551168738452298,
#  'C(Exterior1st_Stucco)',
#  0.09545846501959625,
#  'C(Exterior1st_VinylSd)',
#  6.7830081444133355e-40,
#  'C(Exterior1st_WdSdng)',
#  4.019548490005178e-13,
#  'C(Exterior1st_WdShing)',
#  0.020719483272418016,
#  'C(Exterior2nd_AsbShng)',
#  2.797147998164049e-07,
#  'C(Exterior2nd_AsphShn)',
#  0.3512906904537644,
#  'C(Exterior2nd_BrkCmn)',
#  0.029493814040423453,
#  'C(Exterior2nd_BrkFace)',
#  0.5959428381486467,
#  'C(Exterior2nd_CBlock)',
#  0.24707164420735778,
#  'C(Exterior2nd_CmentBd)',
#  0.0004178204574960935,
#  'C(Exterior2nd_HdBoard)',
#  0.05614353441817297,
#  'C(Exterior2nd_ImStucc)',
#  0.08618336464946377,
#  'C(Exterior2nd_MetalSd)',
#  1.079831157455361e-10,
#  'C(Exterior2nd_Other)',
#  0.10417882188165428,
#  'C(Exterior2nd_Plywood)',
#  0.35764532703292906,
#  'C(Exterior2nd_Stone)',
#  0.4814052160453911,
#  'C(Exterior2nd_Stucco)',
#  0.027564473076372144,
#  'C(Exterior2nd_VinylSd)',
#  3.2791419393181154e-40,
#  'C(Exterior2nd_WdSdng)',
#  1.5821624550320032e-12,
#  'C(Exterior2nd_WdShng)',
#  0.03925218669693112,
#  'C(Fence_GdPrv)',
#  0.5165290893136903,
#  'C(Fence_GdWo)',
#  6.511367545175862e-06,
#  'C(Fence_MnPrv)',
#  7.057768164541235e-09,
#  'C(Fence_MnWw)',
#  0.05819981020184102,
#  'C(Fence_None)',
#  9.122146613092723e-12,
#  'C(FireplaceQu_Ex)',
#  6.826206656679955e-16,
#  'C(FireplaceQu_Fa)',
#  0.8212292824498341,
#  'C(FireplaceQu_Gd)',
#  3.73395169121723e-42,
#  'C(FireplaceQu_None)',
#  1.6884906347481857e-97,
#  'C(FireplaceQu_Po)',
#  0.0012838994060027336,
#  'C(FireplaceQu_TA)',
#  2.3480025951421373e-16,
#  'C(Foundation_BrkTil)',
#  1.5620392949516683e-22,
#  'C(Foundation_CBlock)',
#  2.665083354561915e-40,
#  'C(Foundation_PConc)',
#  6.324348216636221e-107,
#  'C(Foundation_Slab)',
#  1.0040887485120466e-09,
#  'C(Foundation_Stone)',
#  0.5766603388069224,
#  'C(Foundation_Wood)',
#  0.7336673480983971,
#  'C(Functional_Maj1)',
#  0.12173950515817804,
#  'C(Functional_Maj2)',
#  7.00973754679271e-05,
#  'C(Functional_Min1)',
#  0.022511008238305607,
#  'C(Functional_Min2)',
#  0.008312825294302998,
#  'C(Functional_Mod)',
#  0.1070363101594036,
#  'C(Functional_Sev)',
#  0.52085754065313,
#  'C(Functional_Typ)',
#  3.033611324130817e-07,
#  'C(GarageCond_Ex)',
#  0.29381285347764663,
#  'C(GarageCond_Fa)',
#  1.1468789962190816e-10,
#  'C(GarageCond_Gd)',
#  0.8414679813670349,
#  'C(GarageCond_None)',
#  8.41396886014304e-37,
#  'C(GarageCond_Po)',
#  0.002712318153434088,
#  'C(GarageCond_TA)',
#  1.9036967905984145e-47,
#  'C(GarageFinish_Fin)',
#  4.114237643251657e-63,
#  'C(GarageFinish_None)',
#  8.41396886014304e-37,
#  'C(GarageFinish_RFn)',
#  3.87070405770728e-20,
#  'C(GarageFinish_Unf)',
#  1.9130817116506865e-67,
#  'C(GarageQual_Ex)',
#  0.5112703279867747,
#  'C(GarageQual_Fa)',
#  5.783291087882981e-10,
#  'C(GarageQual_Gd)',
#  0.06502594698482385,
#  'C(GarageQual_None)',
#  8.41396886014304e-37,
#  'C(GarageQual_Po)',
#  0.01661266876803415,
#  'C(GarageQual_TA)',
#  1.5245386193080404e-38,
#  'C(GarageType_2Types)',
#  0.4430036173211863,
#  'C(GarageType_Attchd)',
#  4.051700131605918e-62,
#  'C(GarageType_Basment)',
#  0.2373376563157002,
#  'C(GarageType_BuiltIn)',
#  7.714772359368029e-18,
#  'C(GarageType_CarPort)',
#  0.0010037995408081581,
#  'C(GarageType_Detchd)',
#  7.722135052450914e-54,
#  'C(GarageType_None)',
#  8.41396886014304e-37,
#  'C(Heating_Floor)',
#  0.03699472118785564,
#  'C(Heating_GasA)',
#  2.60566780611285e-07,
#  'C(Heating_GasW)',
#  0.31854195830029197,
#  'C(Heating_Grav)',
#  1.0233841933312739e-08,
#  'C(Heating_OthW)',
#  0.3171619369682013,
#  'C(Heating_Wall)',
#  0.0028569239019145304,
#  'C(HeatingQC_Ex)',
#  7.45999039485247e-80,
#  'C(HeatingQC_Fa)',
#  3.587550490805309e-12,
#  'C(HeatingQC_Gd)',
#  1.2214138772124019e-06,
#  'C(HeatingQC_Po)',
#  0.10338518143042331,
#  'C(HeatingQC_TA)',
#  1.0051275955626502e-39,
#  'C(HouseStyle_1Story)',
#  0.00383197989690615,
#  'C(HouseStyle_1_5Fin)',
#  3.1866914401512823e-12,
#  'C(HouseStyle_1_5Unf)',
#  5.1804722028126775e-05,
#  'C(HouseStyle_2Story)',
#  1.5656698887566091e-24,
#  'C(HouseStyle_2_5Fin)',
#  0.22644617249442808,
#  'C(HouseStyle_2_5Unf)',
#  0.3367448052043752,
#  'C(HouseStyle_SFoyer)',
#  0.00024159140574170603,
#  'C(HouseStyle_SLvl)',
#  0.6513174179119638,
#  'C(KitchenQual_Ex)',
#  1.57242621069058e-61,
#  'C(KitchenQual_Fa)',
#  8.375019513620127e-17,
#  'C(KitchenQual_Gd)',
#  3.1308080263505164e-59,
#  'C(KitchenQual_TA)',
#  1.9478728169239515e-110,
#  'C(LandContour_Bnk)',
#  1.3934207184929947e-05,
#  'C(LandContour_HLS)',
#  2.159648960896308e-05,
#  'C(LandContour_Low)',
#  0.14417662261321396,
#  'C(LandContour_Lvl)',
#  0.7003610254956019,
#  'C(LandSlope_Gtl)',
#  0.16051046579821857,
#  'C(LandSlope_Mod)',
#  0.27562312624456414,
#  'C(LandSlope_Sev)',
#  0.3343678485886855,
#  'C(LotConfig_Corner)',
#  0.8790832148693332,
#  'C(LotConfig_CulDSac)',
#  1.2442740312140767e-08,
#  'C(LotConfig_FR2)',
#  0.8521262915939569,
#  'C(LotConfig_FR3)',
#  0.38968554997774374,
#  'C(LotConfig_Inside)',
#  0.0006557331550335961,
#  'C(LotShape_IR1)',
#  1.5281522766535725e-21,
#  'C(LotShape_IR2)',
#  1.560492814757088e-06,
#  'C(LotShape_IR3)',
#  0.14973219004863156,
#  'C(LotShape_Reg)',
#  1.3042442347030443e-29,
#  'C(MSSubClass_120)',
#  0.000374260665487756,
#  'C(MSSubClass_150)',
#  nan,
#  'C(MSSubClass_160)',
#  9.97690629987064e-06,
#  'C(MSSubClass_180)',
#  3.193254024762481e-05,
#  'C(MSSubClass_190)',
#  5.9234194905538495e-05,
#  'C(MSSubClass_20)',
#  0.036249904146983696,
#  'C(MSSubClass_30)',
#  3.0280061194040617e-38,
#  'C(MSSubClass_40)',
#  0.4413389181437529,
#  'C(MSSubClass_45)',
#  0.00010307178199759589,
#  'C(MSSubClass_50)',
#  2.442160983070777e-11,
#  'C(MSSubClass_60)',
#  1.1500480390068295e-57,
#  'C(MSSubClass_70)',
#  0.2348497130857213,
#  'C(MSSubClass_75)',
#  0.6818766598957475,
#  'C(MSSubClass_80)',
#  0.9654635533300852,
#  'C(MSSubClass_85)',
#  0.1485075396138889,
#  'C(MSSubClass_90)',
#  7.375814121224275e-06,
#  'C(MSZoning_FV)',
#  4.027717658884477e-06,
#  'C(MSZoning_RH)',
#  0.0057230258138015015,
#  'C(MSZoning_RL)',
#  1.658552718975973e-31,
#  'C(MSZoning_RM)',
#  1.1121342878121686e-42,
#  'C(MSZoning_all)',
#  3.964933878645071e-13,
#  'C(MasVnrType_BrkCmn)',
#  0.0959806301169765,
#  'C(MasVnrType_BrkFace)',
#  3.309614747891063e-19,
#  'C(MasVnrType_None)',
#  1.336543590115746e-53,
#  'C(MasVnrType_Stone)',
#  3.447602059673579e-34,
#  'C(MiscFeature_Gar2)',
#  0.9505640490321362,
#  'C(MiscFeature_None)',
#  0.003061767987776185,
#  'C(MiscFeature_Othr)',
#  0.017995408238502007,
#  'C(MiscFeature_Shed)',
#  0.005485244997828213,
#  'C(MiscFeature_TenC)',
#  0.3104356408009295,
#  'C(MoSold_1)',
#  0.23735072911130461,
#  'C(MoSold_10)',
#  0.924002119007872,
#  'C(MoSold_11)',
#  0.2453154849245093,
#  'C(MoSold_12)',
#  0.45341699131414626,
#  'C(MoSold_2)',
#  0.6725789546603056,
#  'C(MoSold_3)',
#  0.8707371380793513,
#  'C(MoSold_4)',
#  0.10393855863049169,
#  'C(MoSold_5)',
#  0.13073535527700206,
#  'C(MoSold_6)',
#  0.8571153040452806,
#  'C(MoSold_7)',
#  0.43372390080775636,
#  'C(MoSold_8)',
#  0.4697506218107612,
#  'C(MoSold_9)',
#  0.13018455761190356,
#  'C(Neighborhood_Blmngtn)',
#  0.13128246133535404,
#  'C(Neighborhood_Blueste)',
#  0.4842653263966956,
#  'C(Neighborhood_BrDale)',
#  1.4993739978919814e-06,
#  'C(Neighborhood_BrkSide)',
#  1.4983344910617595e-11,
#  'C(Neighborhood_ClearCr)',
#  0.003854843032494911,
#  'C(Neighborhood_CollgCr)',
#  5.845124803957761e-06,
#  'C(Neighborhood_Crawfor)',
#  0.0008752234217123926,
#  'C(Neighborhood_Edwards)',
#  2.9672099038888775e-16,
#  'C(Neighborhood_Gilbert)',
#  0.0025490719088907873,
#  'C(Neighborhood_IDOTRR)',
#  1.8409740953909925e-19,
#  'C(Neighborhood_MeadowV)',
#  9.76505696380346e-09,
#  'C(Neighborhood_Mitchel)',
#  0.10826408491594665,
#  'C(Neighborhood_NAmes)',
#  1.443094244961564e-10,
#  'C(Neighborhood_NPkVill)',
#  0.23531935773023505,
#  'C(Neighborhood_NWAmes)',
#  0.01931484449874055,
#  'C(Neighborhood_NoRidge)',
#  3.1524587651511623e-27,
#  'C(Neighborhood_NridgHt)',
#  8.749375027266612e-44,
#  'C(Neighborhood_OldTown)',
#  2.4819112694009733e-19,
#  'C(Neighborhood_SWISU)',
#  0.01905054362158798,
#  'C(Neighborhood_Sawyer)',
#  2.4268483490717608e-06,
#  'C(Neighborhood_SawyerW)',
#  0.1909355080372098,
#  'C(Neighborhood_Somerst)',
#  5.2082565839385853e-11,
#  'C(Neighborhood_StoneBr)',
#  8.866010114476793e-13,
#  'C(Neighborhood_Timber)',
#  9.798468905768102e-08,
#  'C(Neighborhood_Veenker)',
#  0.007586508430058367,
#  'C(OverallQual_1)',
#  1.3448861716816229e-05,
#  'C(OverallQual_10)',
#  2.0221697549649075e-22,
#  'C(OverallQual_2)',
#  1.7460866379710045e-07,
#  'C(OverallQual_3)',
#  5.4045852122241316e-15,
#  'C(OverallQual_4)',
#  1.0684287084318655e-41,
#  'C(OverallQual_5)',
#  2.8497431532156623e-49,
#  'C(OverallQual_6)',
#  0.0014267895583185187,
#  'C(OverallQual_7)',
#  2.6105230898296222e-24,
#  'C(OverallQual_8)',
#  7.410359471262543e-66,
#  'C(OverallQual_9)',
#  9.29744175439466e-40,
#  'C(PavedDrive_N)',
#  5.953332887955667e-29,
#  'C(PavedDrive_P)',
#  0.00026624820039351007,
#  'C(PavedDrive_Y)',
#  9.767416714014634e-32,
#  'C(PoolQC_Ex)',
#  0.0010971633977648724,
#  'C(PoolQC_Fa)',
#  0.3881427812436964,
#  'C(PoolQC_Gd)',
#  0.4833927912964572,
#  'C(PoolQC_None)',
#  0.007599402199821438,
#  'C(RoofMatl_ClyTile)',
#  0.9180190211794287,
#  'C(RoofMatl_CompShg)',
#  0.0005822643262022253,
#  'C(RoofMatl_Membran)',
#  0.3535716757823316,
#  'C(RoofMatl_Metal)',
#  0.8478336814109436,
#  'C(RoofMatl_Roll)',
#  0.6231454346630927,
#  'C(RoofMatl_TarandGrv)',
#  0.7137979877459872,
#  'C(RoofMatl_WdShake)',
#  0.04301737155277577,
#  'C(RoofMatl_WdShngl)',
#  5.221228881313341e-06,
#  'C(RoofStyle_Flat)',
#  0.3702564843508225,
#  'C(RoofStyle_Gable)',
#  3.563862903375778e-13,
#  'C(RoofStyle_Gambrel)',
#  0.05897532838191982,
#  'C(RoofStyle_Hip)',
#  2.104874873448572e-14,
#  'C(RoofStyle_Mansard)',
#  0.8247249356864831,
#  'C(RoofStyle_Shed)',
#  0.3084790904808581,
#  'C(SaleCondition_Abnorml)',
#  6.728798362207525e-10,
#  'C(SaleCondition_AdjLand)',
#  0.013040488507405868,
#  'C(SaleCondition_Alloca)',
#  0.3400876521669385,
#  'C(SaleCondition_Family)',
#  0.0817637478746061,
#  'C(SaleCondition_Normal)',
#  9.697550964881062e-05,
#  'C(SaleCondition_Partial)',
#  3.851806373493091e-37,
#  'C(SaleType_COD)',
#  0.0010358671761404403,
#  'C(SaleType_CWD)',
#  0.38237681694168635,
#  'C(SaleType_Con)',
#  0.10329120156744541,
#  'C(SaleType_ConLD)',
#  0.0585591360758226,
#  'C(SaleType_ConLI)',
#  0.9070738206895514,
#  'C(SaleType_ConLw)',
#  0.15387163908469065,
#  'C(SaleType_New)',
#  3.063236135980908e-38,
#  'C(SaleType_Oth)',
#  0.13012623175312707,
#  'C(SaleType_WD)',
#  2.980666792158013e-16,
#  'C(Street_Grvl)',
#  0.02837964682902506,
#  'C(Street_Pave)',
#  0.028379646829025613,
#  'C(Utilities_AllPub)',
#  0.6296085870536472,
#  'C(Utilities_NoSeWa)',
#  0.629608587053528,
#  'C(YrSold_2006)',
#  0.5842254124577,
#  'C(YrSold_2007)',
#  0.16976874645247697,
#  'C(YrSold_2008)',
#  0.6292843177157199,
#  'C(YrSold_2009)',
#  0.4215971238925169,
#  'C(YrSold_2010)',
#  0.41746212829772933]
